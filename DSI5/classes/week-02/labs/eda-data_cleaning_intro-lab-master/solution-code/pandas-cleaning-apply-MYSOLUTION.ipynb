# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Lab: Cleaning Rock Song Data
#
# _Authors: Dave Yerrington (SF)_
#
# ---

# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### 1. Load `rock.csv` and do an initial examination of its data columns.

# %%
rockfile = "../datasets/rock.csv"

# %%
# Load the data.

df = pd.read_csv(rockfile)

# %%
# Look at the information regarding its columns.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 8 columns):
# Song Clean      2230 non-null object
# ARTIST CLEAN    2230 non-null object
# Release Year    1653 non-null object
# COMBINED        2230 non-null object
# First?          2230 non-null int64
# Year?           2230 non-null int64
# PlayCount       2230 non-null int64
# F*G             2230 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 139.5+ KB

# %%
df.dtypes
# Out:
# Song Clean      object
# ARTIST CLEAN    object
# Release Year    object
# COMBINED        object
# First?           int64
# Year?            int64
# PlayCount        int64
# F*G              int64
# dtype: object

# %%
df.sample(10)
# Out:
#                                              Song Clean  \
# 2097                                    Mysterious Ways
# 1144                                    I Melt With You
# 392                                      Southern Cross
# 1196                                    Come As You Are
# 1478                     Let's Spend the Night Together
# 934                                          Small Town
# 1357                                 Fat Bottomed Girls
# 1766  Everybody's Got Something To Hide Except Me An...
# 1349                                             Blurry
# 1129                                 The Memory Remains
#
#                ARTIST CLEAN Release Year  \
# 2097                     U2         1991
# 1144         Modern English         1982
# 392   Crosby, Stills & Nash         1982
# 1196                Nirvana         1991
# 1478         Rolling Stones         1967
# 934         John Mellencamp         1985
# 1357                  Queen         1978
# 1766            The Beatles         1968
# 1349         Puddle of Mudd         2001
# 1129              Metallica         1997
#
#                                                COMBINED  First?  Year?  \
# 2097                              Mysterious Ways by U2       1      1
# 1144                  I Melt With You by Modern English       1      1
# 392             Southern Cross by Crosby, Stills & Nash       1      1
# 1196                         Come As You Are by Nirvana       1      1
# 1478   Let's Spend the Night Together by Rolling Stones       1      1
# 934                       Small Town by John Mellencamp       1      1
# 1357                        Fat Bottomed Girls by Queen       1      1
# 1766  Everybody's Got Something To Hide Except Me An...       1      1
# 1349                           Blurry by Puddle of Mudd       1      1
# 1129                    The Memory Remains by Metallica       1      1
#
#       PlayCount  F*G
# 2097         38   38
# 1144         15   15
# 392           9    9
# 1196         39   39
# 1478          6    6
# 934          55   55
# 1357         70   70
# 1766          1    1
# 1349          1    1
# 1129          3    3

# %% [markdown]
# ### 2.  Clean up the column names.
#
# Let's clean up the column names. There are two ways we can accomplish this:
#
# #### 2.A Change the column names when you import the data using `pd.read_csv()`.
#
# Notice that, when passing `names=[..A LIST OF STRING..]` with a number of columns that matches the number of strings in the passed list, you replace the column names.
#
# NOTE: When you create custom column names, the first row of the `.csv` already represents a header. It is important to tell `pandas` to skip that row. The `skiprows=1` keyword argument to `read_csv()` will tell `pandas` to skip the first row.

# %%
df.columns
# Out:
# Index(['Song Clean', 'ARTIST CLEAN', 'Release Year', 'COMBINED', 'First?',
#        'Year?', 'PlayCount', 'F*G'],
#       dtype='object')

# %%
import string
# the string library has default strings that contain all letters or numbers
uppercase = string.ascii_uppercase
lowercase = string.ascii_lowercase

df.columns = [''.join([c.lower() for c in column if c in uppercase+lowercase]) for column in df.columns]

# %%
df.columns
# Out:
# Index(['songclean', 'artistclean', 'releaseyear', 'combined', 'first', 'year',
#        'playcount', 'fg'],
#       dtype='object')

# %% [markdown]
# #### 2.B Change column names using the `.rename()` function.
#
# The `.rename()` function takes an argument, `columns=name_dict`, in which `name_dict` is a dictionary containing the original column names as keys and the new column names as values.

# %%
# Change the column names using the `.rename()` function.
df = df.rename(columns = lambda column : ''.join([c.lower() for c in column if c in uppercase+lowercase]))

# %%
df.head(2)
# Out:
#           songclean  artistclean releaseyear                         combined  \
# 0  Caught Up in You  .38 Special        1982  Caught Up in You by .38 Special
# 1      Fantasy Girl  .38 Special         NaN      Fantasy Girl by .38 Special
#
#    first  year  playcount  fg
# 0      1     1         82  82
# 1      1     0          3   0

# %% [markdown]
# #### 2.C Reassigning the `.columns` attribute of a DataFrame.
#
# You can also just reassign the `.columns` attribute to a list of strings containing the new column names.
#
# The only caveat with reassigning `.columns` is that you have to reassign all of the column names at once. You can't partially replace a value by working on `.columns` directly. You have to reassign `.columns` with a list of equal length.

# %%
# Replace the column names by reassigning the `.columns` attribute.
df.columns = [''.join([c.lower() for c in column if c in uppercase+lowercase]) for column in df.columns]

# %%
df.columns
# Out:
# Index(['songclean', 'artistclean', 'releaseyear', 'combined', 'first', 'year',
#        'playcount', 'fg'],
#       dtype='object')

# %% [markdown]
# ### 3. Subsetting data where null values exist.
#
# We have mixed `str` and `NaN` values in the `release` column. `NaN` stands for "not a number" and is the way `pandas` handles "nulls" or nonexistent data. We can use the `.isnull()` method of a Series to find null values.
#
# Print the header of the data subset to where the `release` column is null values.

# %%
df.columns
# Out:
# Index(['songclean', 'artistclean', 'releaseyear', 'combined', 'first', 'year',
#        'playcount', 'fg'],
#       dtype='object')

# %%
df['releaseyear'].isnull()
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10       True
# 11      False
# 12      False
# 13       True
# 14      False
# 15      False
# 16       True
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24       True
# 25       True
# 26       True
# 27      False
# 28      False
# 29       True
#         ...
# 2200    False
# 2201    False
# 2202    False
# 2203     True
# 2204    False
# 2205     True
# 2206     True
# 2207    False
# 2208     True
# 2209    False
# 2210    False
# 2211    False
# 2212    False
# 2213    False
# 2214    False
# 2215     True
# 2216     True
# 2217    False
# 2218     True
# 2219    False
# 2220    False
# 2221     True
# 2222     True
# 2223    False
# 2224    False
# 2225     True
# 2226    False
# 2227    False
# 2228    False
# 2229    False
# Name: releaseyear, Length: 2230, dtype: bool

# %%
# Show records where df['release'] is null
df[df['releaseyear'].isnull()].head()
# Out:
#                  songclean  artistclean releaseyear  \
# 1             Fantasy Girl  .38 Special         NaN
# 10   Baby, Please Don't Go        AC/DC         NaN
# 13  CAN'T STOP ROCK'N'ROLL        AC/DC         NaN
# 16        Girls Got Rhythm        AC/DC         NaN
# 24         Let's Get It Up        AC/DC         NaN
#
#                            combined  first  year  playcount  fg
# 1       Fantasy Girl by .38 Special      1     0          3   0
# 10   Baby, Please Don't Go by AC/DC      1     0          1   0
# 13  CAN'T STOP ROCK'N'ROLL by AC/DC      1     0          5   0
# 16        Girls Got Rhythm by AC/DC      1     0         24   0
# 24         Let's Get It Up by AC/DC      1     0          4   0

# %%
df[~df['releaseyear'].isnull()].head()
# Out:
#                 songclean   artistclean releaseyear  \
# 0        Caught Up in You   .38 Special        1982
# 2         Hold On Loosely   .38 Special        1981
# 3  Rockin' Into the Night   .38 Special        1980
# 4       Art For Arts Sake          10cc        1975
# 5              Kryptonite  3 Doors Down        2000
#
#                                 combined  first  year  playcount  fg
# 0        Caught Up in You by .38 Special      1     1         82  82
# 2         Hold On Loosely by .38 Special      1     1         85  85
# 3  Rockin' Into the Night by .38 Special      1     1         18  18
# 4              Art For Arts Sake by 10cc      1     1          1   1
# 5             Kryptonite by 3 Doors Down      1     1         13  13

# %% [markdown]
# ### 4. Update slices of your DataFrame based on mask selection/slices.
#
# In many scenarios, we want to upate values in our DataFrame according to criteria. Let's say we wanted to set all of the null values in `release` to 0.
#
# With newer versions of `pandas`, in order to manipulate data in the original DataFrame, we have to use `.loc` while performing reassignment using a mask and an index.
#
# For example, the following won't always work:
# ```python
# df[row_mask]['column_name'] = new_value
# ```
#
# The best way to accomplish the same task is:
# ```python
# df.loc[row_mask, 'column_name'] = new_value
# ```
#
# For multiple column assignment, you would use:
# ```python
# df.loc[row_mask, ['col_1', 'col_2', 'col_3']] = new_value
# ```
#
# #### 4.A Let's try it out. Make all of the null values in `release` 0.

# %%
# Replace release nulls with 0

# %%
df[df['releaseyear'].isnull()].index
# Out:
# Int64Index([   1,   10,   13,   16,   24,   25,   26,   29,   31,   35,
#             ...
#             2203, 2205, 2206, 2208, 2215, 2216, 2218, 2221, 2222, 2225],
#            dtype='int64', length=577)

# %%
df.loc[df[df['releaseyear'].isnull()].index, 'releaseyear'] = 0

# %%
# cheat df['releaseyear'] = df['releaseyear'].fillna(0)

# %% [markdown]
# #### 4.B Verify that `release` contains no null values.

# %%
df[df['releaseyear'].isnull()]
# Out:
# Empty DataFrame
# Columns: [songclean, artistclean, releaseyear, combined, first, year, playcount, fg]
# Index: []

# %% [markdown]
# ### 5. Ensure that the data types of the columns make sense.
#
# Verifying column data types is a critical part of data munging. If columns have the wrong data type, then there is usually corrupted or incorrect data in some of the observations.
#
# #### 5.A Look at the data types for the columns. Are any incorrect given what the data represents?

# %%
# A:

df.dtypes
# Out:
# songclean      object
# artistclean    object
# releaseyear    object
# combined       object
# first           int64
# year            int64
# playcount       int64
# fg              int64
# dtype: object

# %%
df.sample(5)
# Out:
#                                      songclean          artistclean  \
# 1350                                      Amie  Pure Prairie League
# 1099                        Sweet Home Alabama       Lynyrd Skynyrd
# 166                    Only The Good Die Young           Billy Joel
# 1111  You Took The Words Right Out Of My Mouth            Meat Loaf
# 759                                   Patience        Guns N' Roses
#
#      releaseyear                                           combined  first  \
# 1350           0                        Amie by Pure Prairie League      1
# 1099        1974               Sweet Home Alabama by Lynyrd Skynyrd      1
# 166         1977              Only The Good Die Young by Billy Joel      1
# 1111        1977  You Took The Words Right Out Of My Mouth by Me...      1
# 759         1988                          Patience by Guns N' Roses      1
#
#       year  playcount  fg
# 1350     0          4   0
# 1099     1         95  95
# 166      1         21  21
# 1111     1          9   9
# 759      1         21  21

# %% [markdown]
# ##### COMMENT: releaseyear as object?!?!

# %% [markdown]
# ### 6. Investigate and clean up the `release` column.
#
# The `release` column is a string data type when it should be an integer.
#
# #### 6.A Figure out what value(s) are causing the `release` column to be encoded as a string instead of an integer.

# %%
df['releaseyear'].unique()
# Out:
# array(['1982', 0, '1981', '1980', '1975', '2000', '2002', '1992', '1985',
#        '1993', '1976', '1995', '1979', '1984', '1977', '1990', '1986',
#        '1974', '2014', '1987', '1973', '2001', '1989', '1997', '1971',
#        '1972', '1994', '1970', '1966', '1965', '1983', '1955', '1978',
#        '1969', '1999', '1968', '1988', '1962', '2007', '1967', '1958',
#        '1071', '1996', '1991', '2005', '2011', '2004', '2012', '2003',
#        '1998', '2008', '1964', '2013', '2006', 'SONGFACTS.COM', '1963',
#        '1961'], dtype=object)

# %%
for c in df['releaseyear']:
    try:
        float(c)
    except:
        print(c)
# Out:
# SONGFACTS.COM

# %% [markdown]
# #### 6.B Look at the rows in which there is incorrect data in the `release` column.

# %%
df[df['releaseyear']=='SONGFACTS.COM']
# Out:
#            songclean     artistclean    releaseyear  \
# 1504  Bullfrog Blues  Rory Gallagher  SONGFACTS.COM
#
#                               combined  first  year  playcount  fg
# 1504  Bullfrog Blues by Rory Gallagher      1     1          1   1

# %% [markdown]
# #### 6.C. Clean up the data. Normally we may replace the offending data with null np.nan values, however we previously converted all of the nan values in the release column to zeros so we might as well continue with the same practice. Replacing with 0 (or nan) will allow us to convert the column to numeric.

# %%
df.loc[df[df['releaseyear']=='SONGFACTS.COM'].index, 'releaseyear'] = np.nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 8 columns):
# songclean      2230 non-null object
# artistclean    2230 non-null object
# releaseyear    2229 non-null object
# combined       2230 non-null object
# first          2230 non-null int64
# year           2230 non-null int64
# playcount      2230 non-null int64
# fg             2230 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 139.5+ KB

# %%
df['releaseyear'] = df['releaseyear'].astype(float)

# %%
df.dtypes
# Out:
# songclean       object
# artistclean     object
# releaseyear    float64
# combined        object
# first            int64
# year             int64
# playcount        int64
# fg               int64
# dtype: object

# %% [markdown]
# ### 7. Get summary statistics for the `release` column using the `.describe()` function.
#
# Now that the `release` column is finally a numeric data type, we can apply the `.describe()` function.
#
# #### 7.A Print out the summary stats for the `release` column. What is the earliest and latest release date?

# %%
# A:
df['releaseyear'].describe()
# Out:
# count    2229.000000
# mean     1465.988784
# std       866.834789
# min         0.000000
# 25%         0.000000
# 50%      1973.000000
# 75%      1981.000000
# max      2014.000000
# Name: releaseyear, dtype: float64

# %%
df[df['releaseyear']>0]['releaseyear'].describe()
# Out:
# count    1652.000000
# mean     1978.019976
# std        24.191247
# min      1071.000000
# 25%      1971.000000
# 50%      1977.000000
# 75%      1984.000000
# max      2014.000000
# Name: releaseyear, dtype: float64

# %% [markdown]
# #### 7.B Based on the summary statistics, is there anything else wrong with the `release` column?

# %% [markdown]
# _Looking at the DataFrame that contains the year 1071, we can see that the year was probably corrupted and should be replaced with something else if possible._

# %% [markdown]
# ### 8. Make changes and investigate using custom functions with `.apply()`.
#
# Let's say we want to traverse every single row in our data set and apply a function to that row.
#
# #### 8.A Write a function that will take a row of a DataFrame and print out the song, artist, and whether or not the release date is < 1970.

# %%
# A:

def print_info(row):
    print(row['songclean'],row['artistclean'],row['releaseyear']<1970)

# %%
def print_info(row):
    if row['releaseyear']<1970:
        print(row['songclean'],row['artistclean'],'this is old')
    else:
        print(row['songclean'],row['artistclean'],'this is recent')

# %% [markdown]
# #### 8.B Using the `.apply()` function, apply the function you wrote to the first four rows of the DataFrame.
#
# You will need to tell the `apply` function to operate row by row. Setting the keyword argument as `axis=1` indicates that the function should be applied to each row individually.

# %%
df.apply(lambda x:type(x), axis=0)
# Out:
# songclean      <class 'pandas.core.series.Series'>
# artistclean    <class 'pandas.core.series.Series'>
# releaseyear    <class 'pandas.core.series.Series'>
# combined       <class 'pandas.core.series.Series'>
# first          <class 'pandas.core.series.Series'>
# year           <class 'pandas.core.series.Series'>
# playcount      <class 'pandas.core.series.Series'>
# fg             <class 'pandas.core.series.Series'>
# dtype: object

# %%
# THIS IS BY COLUMNS --> ERROR!
df.apply(print_info, axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-4120c08106a1> in <module>()
#       1 # THIS IS BY COLUMNS --> ERROR!
# ----> 2 df.apply(print_info, axis=0)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     316                                       *self.args, **self.kwds)
#     317
# --> 318         return super(FrameRowApply, self).get_result()
#     319
#     320     def apply_broadcast(self):
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-35-8196ce419a44> in print_info(row)
#       1 def print_info(row):
# ----> 2     if row['releaseyear']<1970:
#       3         print(row['songclean'],row['artistclean'],'this is old')
#       4     else:
#       5         print(row['songclean'],row['artistclean'],'this is recent')
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: ('releaseyear', 'occurred at index songclean')

# %%
for column_name in df:
    print(column_name)
# Out:
# songclean
# artistclean
# releaseyear
# combined
# first
# year
# playcount
# fg

# %%
for i in df.index.values[:3]:
    print(type(df.loc[i]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
for i in df.index.values[:3]:
    print_info(df.loc[i])
# Out:
# Caught Up in You .38 Special this is recent
# Fantasy Girl .38 Special this is old
# Hold On Loosely .38 Special this is recent

# %%
df.apply(lambda x:(type(x),x['songclean']), axis=1)
# Out:
# 0       (<class 'pandas.core.series.Series'>, Caught U...
# 1       (<class 'pandas.core.series.Series'>, Fantasy ...
# 2       (<class 'pandas.core.series.Series'>, Hold On ...
# 3       (<class 'pandas.core.series.Series'>, Rockin' ...
# 4       (<class 'pandas.core.series.Series'>, Art For ...
# 5       (<class 'pandas.core.series.Series'>, Kryptonite)
# 6            (<class 'pandas.core.series.Series'>, Loser)
# 7       (<class 'pandas.core.series.Series'>, When I'm...
# 8       (<class 'pandas.core.series.Series'>, What's Up?)
# 9       (<class 'pandas.core.series.Series'>, Take On Me)
# 10      (<class 'pandas.core.series.Series'>, Baby, Pl...
# 11      (<class 'pandas.core.series.Series'>, Back In ...
# 12         (<class 'pandas.core.series.Series'>, Big Gun)
# 13      (<class 'pandas.core.series.Series'>, CAN'T ST...
# 14      (<class 'pandas.core.series.Series'>, Dirty De...
# 15      (<class 'pandas.core.series.Series'>, For Thos...
# 16      (<class 'pandas.core.series.Series'>, Girls Go...
# 17      (<class 'pandas.core.series.Series'>, Hard As ...
# 18      (<class 'pandas.core.series.Series'>, Have a D...
# 19      (<class 'pandas.core.series.Series'>, Hells Be...
# 20      (<class 'pandas.core.series.Series'>, Highway ...
# 21      (<class 'pandas.core.series.Series'>, It's A L...
# 22       (<class 'pandas.core.series.Series'>, Jailbreak)
# 23      (<class 'pandas.core.series.Series'>, Let Ther...
# 24      (<class 'pandas.core.series.Series'>, Let's Ge...
# 25       (<class 'pandas.core.series.Series'>, Live Wire)
# 26      (<class 'pandas.core.series.Series'>, Moneytalks)
# 27      (<class 'pandas.core.series.Series'>, Night Pr...
# 28      (<class 'pandas.core.series.Series'>, Rock and...
# 29      (<class 'pandas.core.series.Series'>, Shoot To...
#                               ...
# 2200    (<class 'pandas.core.series.Series'>, Owner of...
# 2201    (<class 'pandas.core.series.Series'>, Roundabout)
# 2202    (<class 'pandas.core.series.Series'>, Starship...
# 2203    (<class 'pandas.core.series.Series'>, Wonderou...
# 2204    (<class 'pandas.core.series.Series'>, Yours Is...
# 2205    (<class 'pandas.core.series.Series'>, Tell Me ...
# 2206    (<class 'pandas.core.series.Series'>, Who's Be...
# 2207    (<class 'pandas.core.series.Series'>, Time of ...
# 2208    (<class 'pandas.core.series.Series'>, A Fool f...
# 2209    (<class 'pandas.core.series.Series'>, Arrested...
# 2210    (<class 'pandas.core.series.Series'>, Beer Dri...
# 2211    (<class 'pandas.core.series.Series'>, Cheap Su...
# 2212    (<class 'pandas.core.series.Series'>, Gimme Al...
# 2213    (<class 'pandas.core.series.Series'>, Got Me U...
# 2214    (<class 'pandas.core.series.Series'>, Heard It...
# 2215    (<class 'pandas.core.series.Series'>, I Thank ...
# 2216    (<class 'pandas.core.series.Series'>, I'm Bad,...
# 2217    (<class 'pandas.core.series.Series'>, Jesus Ju...
# 2218    (<class 'pandas.core.series.Series'>, Just Got...
# 2219     (<class 'pandas.core.series.Series'>, La Grange)
# 2220          (<class 'pandas.core.series.Series'>, Legs)
# 2221    (<class 'pandas.core.series.Series'>, My Head'...
# 2222    (<class 'pandas.core.series.Series'>, Party On...
# 2223    (<class 'pandas.core.series.Series'>, Pearl Ne...
# 2224    (<class 'pandas.core.series.Series'>, Sharp Dr...
# 2225    (<class 'pandas.core.series.Series'>, She Love...
# 2226    (<class 'pandas.core.series.Series'>, Tube Sna...
# 2227          (<class 'pandas.core.series.Series'>, Tush)
# 2228    (<class 'pandas.core.series.Series'>, TV Dinners)
# 2229    (<class 'pandas.core.series.Series'>, WAITIN' ...
# Length: 2230, dtype: object

# %%
# This is by rows
df.apply(print_info, axis=1)
# Out:
# Caught Up in You .38 Special this is recent
# Fantasy Girl .38 Special this is old
# Hold On Loosely .38 Special this is recent
# Rockin' Into the Night .38 Special this is recent
# Art For Arts Sake 10cc this is recent
# Kryptonite 3 Doors Down this is recent
# Loser 3 Doors Down this is recent
# When I'm Gone 3 Doors Down this is recent
# What's Up? 4 Non Blondes this is recent
# Take On Me a-ha this is recent
# Baby, Please Don't Go AC/DC this is old
# Back In Black AC/DC this is recent
# Big Gun AC/DC this is recent
# Here I Go Again Whitesnake this is recent
# Is This Love Whitesnake this is recent
# Slide It In Whitesnake this is recent
# Slow An' Easy Whitesnake this is old
# Still of the Night Whitesnake this is old
# Who Are You? Why Not this is old
# PLAY THAT FUNKY MUSIC Wild Cherry this is recent
# Night Moves Wildlife this is old
# We've Got Tonight Wildlife this is old
# Can't Get Enough Winger this is old
# Headed For A Heartbreak Winger this is old
# Seventeen Winger this is old
# Persephone Wishbone Ash this is recent
# Summertime Girls Y&T this is old
# Changes Yes this is recent
# I've Seen All Good People Yes this is recent
# It Can Happen Yes this is recent
# Leave It Yes this is recent
# Long Distance Runaround Yes this is recent
# Owner of a Lonely Heart Yes this is recent
# Roundabout Yes this is recent
# Starship Trooper Yes this is recent
# Wonderous Stories Yes this is old
# Yours Is No Disgrace Yes this is recent
# Tell Me What You Want Zebra this is old
# Who's Behind The Door Zebra this is old
# Time of the Season Zombies this is old
# A Fool for Your Stockings ZZ Top this is old
# Arrested For Driving While Blind ZZ Top this is recent
# Beer Drinkers & Hell Raisers ZZ Top this is recent
# Cheap Sunglasses ZZ Top this is recent
# Gimme All Your Lovin ZZ Top this is recent
# Got Me Under Pressure ZZ Top this is recent
# Heard It On the X ZZ Top this is recent
# I Thank You ZZ Top this is old
# I'm Bad, I'm Nationwide ZZ Top this is old
# Jesus Just Left Chicago ZZ Top this is recent
# Just Got Paid ZZ Top this is old
# La Grange ZZ Top this is recent
# Legs ZZ Top this is recent
# My Head's In Mississippi ZZ Top this is old
# Party On The Patio ZZ Top this is old
# Pearl Necklace ZZ Top this is recent
# Sharp Dressed Man ZZ Top this is recent
# She Loves My Automobile ZZ Top this is old
# Tube Snake Boogie ZZ Top this is recent
# Tush ZZ Top this is recent
# TV Dinners ZZ Top this is recent
# WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO ZZ Top this is recent
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21      None
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27      None
# 28      None
# 29      None
#         ...
# 2200    None
# 2201    None
# 2202    None
# 2203    None
# 2204    None
# 2205    None
# 2206    None
# 2207    None
# 2208    None
# 2209    None
# 2210    None
# 2211    None
# 2212    None
# 2213    None
# 2214    None
# 2215    None
# 2216    None
# 2217    None
# 2218    None
# 2219    None
# 2220    None
# 2221    None
# 2222    None
# 2223    None
# 2224    None
# 2225    None
# 2226    None
# 2227    None
# 2228    None
# 2229    None
# Length: 2230, dtype: object

# %% [markdown]
# You'll notice that there will be a final output Series of `None` values. The `.apply()` function, if a return value is not specified, will return a Series of `None` values (similar to how the default return for Python functions is `None` when a return statement is not specified).

# %% [markdown]
# ### 9. Write a function that converts cells in a DataFrame to float and otherwise replaces them with `np.nan`.
#
# If applied to our data, it would keep only the numeric information and otherwise input null values.
#
# Recall that the try-except syntax in Python is a great way to try something and take another action if the initial step fails:
#
# ```python
# try:
#     Perform some action.
# except:
#    Perform some other action if the first failed with an error.
# ```
#
# #### 9.A Write the function that takes a column and converts all of its values to float if possible and `np.nan` otherwise. The return value should be the converted Series.

# %%
# A:

def float_or_nan(column):
    new_col = []
    for el in column:
        try:
            new_col.append(float(el))
        except:
            new_col.append(np.nan)
    return new_col

# %%
def element_converter(element):
    try:
        return float(element)
    except:
        return np.nan

def float_or_nan(column):
    return column.map(element_converter)

# %% [markdown]
# #### 9.B Try your function out on the rock song data and ensure the output is what you expected.

# %%
# A:

df.apply(float_or_nan)
# Out:
#       songclean  artistclean  releaseyear  combined  first  year  playcount  \
# 0           NaN          NaN       1982.0       NaN    1.0   1.0       82.0
# 1           NaN          NaN          0.0       NaN    1.0   0.0        3.0
# 2           NaN          NaN       1981.0       NaN    1.0   1.0       85.0
# 3           NaN          NaN       1980.0       NaN    1.0   1.0       18.0
# 4           NaN          NaN       1975.0       NaN    1.0   1.0        1.0
# 5           NaN          NaN       2000.0       NaN    1.0   1.0       13.0
# 6           NaN          NaN       2000.0       NaN    1.0   1.0        1.0
# 7           NaN          NaN       2002.0       NaN    1.0   1.0        6.0
# 8           NaN          NaN       1992.0       NaN    1.0   1.0        3.0
# 9           NaN          NaN       1985.0       NaN    1.0   1.0        1.0
# 10          NaN          NaN          0.0       NaN    1.0   0.0        1.0
# 11          NaN          NaN       1980.0       NaN    1.0   1.0       97.0
# 12          NaN          NaN       1993.0       NaN    1.0   1.0        6.0
# 13          NaN          NaN          0.0       NaN    1.0   0.0        5.0
# 14          NaN          NaN       1976.0       NaN    1.0   1.0       85.0
# 15          NaN          NaN       1981.0       NaN    1.0   1.0       46.0
# 16          NaN          NaN          0.0       NaN    1.0   0.0       24.0
# 17          NaN          NaN       1995.0       NaN    1.0   1.0        1.0
# 18          NaN          NaN       1980.0       NaN    1.0   1.0       39.0
# 19          NaN          NaN       1980.0       NaN    1.0   1.0       74.0
# 20          NaN          NaN       1979.0       NaN    1.0   1.0       92.0
# 21          NaN          NaN       1975.0       NaN    1.0   1.0       39.0
# 22          NaN          NaN       1984.0       NaN    1.0   1.0        1.0
# 23          NaN          NaN       1977.0       NaN    1.0   1.0        3.0
# 24          NaN          NaN          0.0       NaN    1.0   0.0        4.0
# 25          NaN          NaN          0.0       NaN    1.0   0.0        2.0
# 26          NaN          NaN          0.0       NaN    1.0   0.0       20.0
# 27          NaN          NaN       1979.0       NaN    1.0   1.0        1.0
# 28          NaN          NaN       1980.0       NaN    1.0   1.0       21.0
# 29          NaN          NaN          0.0       NaN    1.0   0.0       45.0
# ...         ...          ...          ...       ...    ...   ...        ...
# 2200        NaN          NaN       1983.0       NaN    1.0   1.0       81.0
# 2201        NaN          NaN       1971.0       NaN    1.0   1.0       44.0
# 2202        NaN          NaN       1971.0       NaN    1.0   1.0        1.0
# 2203        NaN          NaN          0.0       NaN    1.0   0.0        5.0
# 2204        NaN          NaN       1971.0       NaN    1.0   1.0        1.0
# 2205        NaN          NaN          0.0       NaN    1.0   0.0        2.0
# 2206        NaN          NaN          0.0       NaN    1.0   0.0        1.0
# 2207        NaN          NaN       1968.0       NaN    1.0   1.0       14.0
# 2208        NaN          NaN          0.0       NaN    1.0   0.0        1.0
# 2209        NaN          NaN       1976.0       NaN    1.0   1.0        1.0
# 2210        NaN          NaN       1973.0       NaN    1.0   1.0        8.0
# 2211        NaN          NaN       1980.0       NaN    1.0   1.0       34.0
# 2212        NaN          NaN       1983.0       NaN    1.0   1.0       86.0
# 2213        NaN          NaN       1983.0       NaN    1.0   1.0       29.0
# 2214        NaN          NaN       1975.0       NaN    1.0   1.0        2.0
# 2215        NaN          NaN          0.0       NaN    1.0   0.0       16.0
# 2216        NaN          NaN          0.0       NaN    1.0   0.0       10.0
# 2217        NaN          NaN       1973.0       NaN    1.0   1.0        6.0
# 2218        NaN          NaN          0.0       NaN    1.0   0.0        2.0
# 2219        NaN          NaN       1973.0       NaN    1.0   1.0      111.0
# 2220        NaN          NaN       1983.0       NaN    1.0   1.0      121.0
# 2221        NaN          NaN          0.0       NaN    1.0   0.0        1.0
# 2222        NaN          NaN          0.0       NaN    1.0   0.0       14.0
# 2223        NaN          NaN       1981.0       NaN    1.0   1.0        5.0
# 2224        NaN          NaN       1983.0       NaN    1.0   1.0      120.0
# 2225        NaN          NaN          0.0       NaN    1.0   0.0        1.0
# 2226        NaN          NaN       1981.0       NaN    1.0   1.0       32.0
# 2227        NaN          NaN       1975.0       NaN    1.0   1.0      109.0
# 2228        NaN          NaN       1983.0       NaN    1.0   1.0        1.0
# 2229        NaN          NaN       1973.0       NaN    1.0   1.0        2.0
#
#          fg
# 0      82.0
# 1       0.0
# 2      85.0
# 3      18.0
# 4       1.0
# 5      13.0
# 6       1.0
# 7       6.0
# 8       3.0
# 9       1.0
# 10      0.0
# 11     97.0
# 12      6.0
# 13      0.0
# 14     85.0
# 15     46.0
# 16      0.0
# 17      1.0
# 18     39.0
# 19     74.0
# 20     92.0
# 21     39.0
# 22      1.0
# 23      3.0
# 24      0.0
# 25      0.0
# 26      0.0
# 27      1.0
# 28     21.0
# 29      0.0
# ...     ...
# 2200   81.0
# 2201   44.0
# 2202    1.0
# 2203    0.0
# 2204    1.0
# 2205    0.0
# 2206    0.0
# 2207   14.0
# 2208    0.0
# 2209    1.0
# 2210    8.0
# 2211   34.0
# 2212   86.0
# 2213   29.0
# 2214    2.0
# 2215    0.0
# 2216    0.0
# 2217    6.0
# 2218    0.0
# 2219  111.0
# 2220  121.0
# 2221    0.0
# 2222    0.0
# 2223    5.0
# 2224  120.0
# 2225    0.0
# 2226   32.0
# 2227  109.0
# 2228    1.0
# 2229    2.0
#
# [2230 rows x 8 columns]

# %% [markdown]
# #### 9.C Describe the new float-only DataFrame.

# %%
df.apply(float_or_nan).describe()
# Out:
#          songclean  artistclean  releaseyear  combined   first         year  \
# count     2.000000          0.0  2229.000000       0.0  2230.0  2230.000000
# mean   1012.000000          NaN  1465.988784       NaN     1.0     0.741256
# std    1367.544515          NaN   866.834789       NaN     0.0     0.438043
# min      45.000000          NaN     0.000000       NaN     1.0     0.000000
# 25%     528.500000          NaN     0.000000       NaN     1.0     0.000000
# 50%    1012.000000          NaN  1973.000000       NaN     1.0     1.000000
# 75%    1495.500000          NaN  1981.000000       NaN     1.0     1.000000
# max    1979.000000          NaN  2014.000000       NaN     1.0     1.000000
#
#          playcount           fg
# count  2230.000000  2230.000000
# mean     16.872646    15.048430
# std      25.302972    25.288366
# min       0.000000     0.000000
# 25%       1.000000     0.000000
# 50%       4.000000     3.000000
# 75%      21.000000    18.000000
# max     142.000000   142.000000
